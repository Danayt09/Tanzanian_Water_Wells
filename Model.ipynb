# %% [markdown]
# # Multiclass Model

# %%
import pandas as pd   
import numpy as np 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

# %%
tz_data = pd.read_csv('tz_data.csv')

# %%
data = tz_data.copy()
data
# Out:
#           id  amount_tsh                  funder  gps_height installer  \
# 0      69572      6000.0                   other        1390     other
# 1       8776         0.0                   other        1399     other
# 2      34310        25.0                   other         686     other
# 3      67743         0.0                   other         263     other
# 4      19728         0.0                   other           0     other
# ...      ...         ...                     ...         ...       ...
# 59395  60739        10.0                   other        1210     other
# 59396  27263      4700.0                   other        1212     other
# 59397  37057         0.0  Government Of Tanzania           0       DWE
# 59398  31282         0.0                   other           0     other
# 59399  26348         0.0              World Bank         191     other
#
#        longitude   latitude                    basin  population  \
# 0      34.938093  -9.856322               Lake Nyasa         109
# 1      34.698766  -2.147466            Lake Victoria         280
# 2      37.460664  -3.821329                  Pangani         250
# 3      38.486161 -11.155298  Ruvuma / Southern Coast          58
# 4      31.130847  -1.825359            Lake Victoria           0
# ...          ...        ...                      ...         ...
# 59395  37.169807  -3.253847                  Pangani         125
# 59396  35.249991  -9.070629                   Rufiji          56
# 59397  34.017087  -8.750434                   Rufiji           0
# 59398  35.861315  -6.378573                   Rufiji           0
# 59399  38.104048  -6.747464              Wami / Ruvu         150
#
#        public_meeting scheme_management  permit  construction_year  \
# 0                True               VWC   False               1999
# 1                True             other    True               2010
# 2                True               VWC    True               2009
# 3                True               VWC    True               1986
# 4                True               VWC    True               2000
# ...               ...               ...     ...                ...
# 59395            True       Water Board    True               1999
# 59396            True               VWC    True               1996
# 59397            True               VWC   False               2000
# 59398            True               VWC    True               2000
# 59399            True               VWC    True               2002
#
#       extraction_type_class payment_type quality_group quantity_group  \
# 0                   gravity     annually          good         enough
# 1                   gravity    never pay          good   insufficient
# 2                   gravity   per bucket          good         enough
# 3               submersible    never pay          good            dry
# 4                   gravity    never pay          good       seasonal
# ...                     ...          ...           ...            ...
# 59395               gravity   per bucket          good         enough
# 59396               gravity     annually          good         enough
# 59397              handpump      monthly      fluoride         enough
# 59398              handpump    never pay          good   insufficient
# 59399              handpump   on failure         salty         enough
#
#                      source waterpoint_type_group  status_group
# 0                    spring    communal standpipe             2
# 1      rainwater harvesting    communal standpipe             2
# 2                       dam    communal standpipe             2
# 3               machine dbh    communal standpipe             0
# 4      rainwater harvesting    communal standpipe             2
# ...                     ...                   ...           ...
# 59395                spring    communal standpipe             2
# 59396                 river    communal standpipe             2
# 59397           machine dbh             hand pump             2
# 59398          shallow well             hand pump             2
# 59399          shallow well             hand pump             2
#
# [59400 rows x 20 columns]

# %%
data['permit'] = data['permit'].astype(int)

# %%
data['public_meeting'] = data['public_meeting'].astype(int)

# %%
data = data.drop('id', axis =1)

# %%
cat_cols = ['funder', 'installer', 'basin', 'scheme_management', 'extraction_type_class', 'payment_type', 'quality_group', 
              'quantity_group', 'source', 'waterpoint_type_group']

num_cols = ['amount_tsh', 'gps_height', 'longitude', 'population', 'public_meeting']

# %%
data = pd.get_dummies(data, columns = cat_cols)

# %%
# Assuming `df` is your DataFrame
bool_columns = data.select_dtypes(include=bool).columns
data[bool_columns] = data[bool_columns].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 76 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   amount_tsh                                59400 non-null  float64
#  1   gps_height                                59400 non-null  int64
#  2   longitude                                 59400 non-null  float64
#  3   latitude                                  59400 non-null  float64
#  4   population                                59400 non-null  int64
#  5   public_meeting                            59400 non-null  int64
#  6   permit                                    59400 non-null  int64
#  7   construction_year                         59400 non-null  int64
#  8   status_group                              59400 non-null  int64
#  9   funder_Danida                             59400 non-null  int64
#  10  funder_Government Of Tanzania             59400 non-null  int64
#  11  funder_Hesawa                             59400 non-null  int64
#  12  funder_Rwssp                              59400 non-null  int64
#  13  funder_World Bank                         59400 non-null  int64
#  14  funder_other                              59400 non-null  int64
#  15  installer_Commu                           59400 non-null  int64
#  16  installer_DANIDA                          59400 non-null  int64
#  17  installer_DWE                             59400 non-null  int64
#  18  installer_Government                      59400 non-null  int64
#  19  installer_RWE                             59400 non-null  int64
#  20  installer_other                           59400 non-null  int64
#  21  basin_Internal                            59400 non-null  int64
#  22  basin_Lake Nyasa                          59400 non-null  int64
#  23  basin_Lake Rukwa                          59400 non-null  int64
#  24  basin_Lake Tanganyika                     59400 non-null  int64
#  25  basin_Lake Victoria                       59400 non-null  int64
#  26  basin_Pangani                             59400 non-null  int64
#  27  basin_Rufiji                              59400 non-null  int64
#  28  basin_Ruvuma / Southern Coast             59400 non-null  int64
#  29  basin_Wami / Ruvu                         59400 non-null  int64
#  30  scheme_management_VWC                     59400 non-null  int64
#  31  scheme_management_WUG                     59400 non-null  int64
#  32  scheme_management_Water Board             59400 non-null  int64
#  33  scheme_management_Water authority         59400 non-null  int64
#  34  scheme_management_other                   59400 non-null  int64
#  35  extraction_type_class_gravity             59400 non-null  int64
#  36  extraction_type_class_handpump            59400 non-null  int64
#  37  extraction_type_class_motorpump           59400 non-null  int64
#  38  extraction_type_class_other               59400 non-null  int64
#  39  extraction_type_class_rope pump           59400 non-null  int64
#  40  extraction_type_class_submersible         59400 non-null  int64
#  41  extraction_type_class_wind-powered        59400 non-null  int64
#  42  payment_type_annually                     59400 non-null  int64
#  43  payment_type_monthly                      59400 non-null  int64
#  44  payment_type_never pay                    59400 non-null  int64
#  45  payment_type_on failure                   59400 non-null  int64
#  46  payment_type_other                        59400 non-null  int64
#  47  payment_type_per bucket                   59400 non-null  int64
#  48  payment_type_unknown                      59400 non-null  int64
#  49  quality_group_colored                     59400 non-null  int64
#  50  quality_group_fluoride                    59400 non-null  int64
#  51  quality_group_good                        59400 non-null  int64
#  52  quality_group_milky                       59400 non-null  int64
#  53  quality_group_salty                       59400 non-null  int64
#  54  quality_group_unknown                     59400 non-null  int64
#  55  quantity_group_dry                        59400 non-null  int64
#  56  quantity_group_enough                     59400 non-null  int64
#  57  quantity_group_insufficient               59400 non-null  int64
#  58  quantity_group_seasonal                   59400 non-null  int64
#  59  quantity_group_unknown                    59400 non-null  int64
#  60  source_dam                                59400 non-null  int64
#  61  source_hand dtw                           59400 non-null  int64
#  62  source_lake                               59400 non-null  int64
#  63  source_machine dbh                        59400 non-null  int64
#  64  source_other                              59400 non-null  int64
#  65  source_rainwater harvesting               59400 non-null  int64
#  66  source_river                              59400 non-null  int64
#  67  source_shallow well                       59400 non-null  int64
#  68  source_spring                             59400 non-null  int64
#  69  source_unknown                            59400 non-null  int64
#  70  waterpoint_type_group_cattle trough       59400 non-null  int64
#  71  waterpoint_type_group_communal standpipe  59400 non-null  int64
#  72  waterpoint_type_group_dam                 59400 non-null  int64
#  73  waterpoint_type_group_hand pump           59400 non-null  int64
#  74  waterpoint_type_group_improved spring     59400 non-null  int64
#  75  waterpoint_type_group_other               59400 non-null  int64
# dtypes: float64(3), int64(73)
# memory usage: 34.4 MB

# %%
X = data.drop('status_group', axis=1)  
y = data['status_group'] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
class ModelWithCV():
    '''Structure to save the model and more easily see its crossvalidation'''
    
    def __init__(self, model, model_name, X, y, cv_now=True):
        self.model = model
        self.name = model_name
        self.X = X
        self.y = y
        # For CV results
        self.cv_results = None
        self.cv_mean = None
        self.cv_median = None
        self.cv_std = None
        #
        if cv_now:
            self.cross_validate()
        
    def cross_validate(self, X=None, y=None, kfolds=10):
        '''
        Perform cross-validation and return results.
        
        Args: 
          X:
            Optional; Training data to perform CV on. Otherwise use X from object
          y:
            Optional; Training data to perform CV on. Otherwise use y from object
          kfolds:
            Optional; Number of folds for CV (default is 10)  
        '''
        
        cv_X = X if X else self.X
        cv_y = y if y else self.y

        self.cv_results = cross_val_score(self.model, cv_X, cv_y, cv=kfolds)
        self.cv_mean = np.mean(self.cv_results)
        self.cv_median = np.median(self.cv_results)
        self.cv_std = np.std(self.cv_results)

        
    def print_cv_summary(self):
        cv_summary = (
        f'''CV Results for `{self.name}` model:
            {self.cv_mean:.5f} ± {self.cv_std:.5f} accuracy
        ''')
        print(cv_summary)

        
    def plot_cv(self, ax):
        '''
        Plot the cross-validation values using the array of results and given 
        Axis for plotting.
        '''
        ax.set_title(f'CV Results for `{self.name}` Model')
        # Thinner violinplot with higher bw
        sns.violinplot(y=self.cv_results, ax=ax, bw=.4)
        sns.swarmplot(
                y=self.cv_results,
                color='orange',
                size=10,
                alpha= 0.8,
                ax=ax
        )

        return ax

# %%
model(X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 model(X_train, X_test, y_train, y_test)
#
# Cell In[24], line 5, in model(X_train, X_test, y_train, y_test)
#       1 def model(X_train, X_test, y_train, y_test):
#       2     if __name__ == '__main__':
#       4         pipe_svc = Pipeline([('scl', StandardScaler()),
# ----> 5                              ('clf', LinearSVC())])
#       7         param_grid = {'clf__C':[0.001, 0.01, 0.1, 1.0],
#       8                       'clf__class_weight':[None, 'balanced']}
#      10         estimator = GridSearchCV(estimator=pipe_svc,
#      11                                  param_grid=param_grid,
#      12                                  n_jobs=-1)
#
# NameError: name 'LinearSVC' is not defined
